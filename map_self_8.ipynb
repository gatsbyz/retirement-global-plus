# %%
import folium
import pandas as pd

# %%
my_map3 = folium.Map(location=[13/133932434766733, 16.10398729508073],
    zoom_start=3)

# %%
#setting Markers for selected cities. 
#NYC

mk = folium.Marker([40.776676, -73.971321])
pp = folium.Popup('NYC')
ic = folium.Icon(color='red')

mk.add_child(ic)
mk.add_child(pp)
my_map3.add_child(mk)

#Hamilton, Bermuda
mk2 = folium.Marker([32.299507, -64.790337 ])
pp2 = folium.Popup('Hamilton, Bermuda')
ic2 = folium.Icon(color='blue')

mk2.add_child(ic2)
mk2.add_child(pp2)
my_map3.add_child(mk2)

#Hong Kong

mk3 = folium.Marker([22.302711, 114.177216])
pp3 = folium.Popup('Hong Kong')
ic3 = folium.Icon(color='orange')

mk3.add_child(ic3)
mk3.add_child(pp3)
my_map3.add_child(mk3)

#Los Angeles 
mk4 = folium.Marker([34.052235, -118.243683])
pp4 = folium.Popup('Los Angeles')
ic4 = folium.Icon(color='green')

mk4.add_child(ic4)
mk4.add_child(pp4)
my_map3.add_child(mk4)

#Paris France
mk5 = folium.Marker([48.864716, 2.349014])
pp5 = folium.Popup("Paris, France")
ic5 = folium.Icon(color='pink')

mk5.add_child(ic5)
mk5.add_child(pp5)
my_map3.add_child(mk5)

#Hamilton Canada
mk6 = folium.Marker([43.255203, -79.843826])
pp6 = folium.Popup("Hamilton, Canada")
ic6 = folium.Icon(color="black")

mk6.add_child(ic6)
mk6.add_child(pp6)
my_map3.add_child(mk6)

#Milan Itialy
mk7 = folium.Marker([45.464664, 9.188540])
pp7 = folium.Popup('Milan, Itialy')
ic7 = folium.Icon(color='purple')

mk7.add_child(ic7)
mk7.add_child(pp7)
my_map3.add_child(mk7)

#Bucaramanga Colombia
mk8 = folium.Marker([7.119349, -73.122742])
pp8 = folium.Popup("Bucaramanga, Colombia")
ic8 = folium.Icon(color='cadetblue')

mk8.add_child(ic8)
mk8.add_child(pp8)
my_map3.add_child(mk8)

# Mardrid Spain
mk9 = folium.Marker([40.416729, -3.703339])
pp9 = folium.Popup("Madrid, Spain")
ic9 = folium.Icon(color="beige")

mk9.add_child(ic9)
mk9.add_child(pp9)
my_map3.add_child(mk9)

#Deli, India
mk10 = folium.Marker([28.679079, 77.069710])
pp10 = folium.Popup("Delhi, India")
ic10 = folium.Icon(color="darkgreen")

mk10.add_child(ic10)
mk10.add_child(pp10)
my_map3.add_child(mk10)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1dfbc96f1e19485352da3c6bc97493d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1dfbc96f1e19485352da3c6bc97493d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a1dfbc96f1e19485352da3c6bc97493d = L.map(
#                 &quot;map_a1dfbc96f1e19485352da3c6bc97493d&quot;,
#                 {
#                     center: [9.706386673729778e-14, 16.10398729508073],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15f198007384f97b58f6777520474bfc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a1dfbc96f1e19485352da3c6bc97493d);
#
#
#             var marker_f725486668a31a7db6024259f31fb5fa = L.marker(
#                 [40.776676, -73.971321],
#                 {}
#             ).addTo(map_a1dfbc96f1e19485352da3c6bc97493d);
#
#
#             var icon_7138f71c1ba6392f1f0aff309659157d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f725486668a31a7db6024259f31fb5fa.setIcon(icon_7138f71c1ba6392f1f0aff309659157d);
#
#
#         var popup_78a4f5e103c5a4fe714b3dd3722761b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1039b075e3690c28d6371b491865f7d2 = $(`&lt;div id=&quot;html_1039b075e3690c28d6371b491865f7d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NYC&lt;/div&gt;`)[0];
#             popup_78a4f5e103c5a4fe714b3dd3722761b7.setContent(html_1039b075e3690c28d6371b491865f7d2);
#
#
#         marker_f725486668a31a7db6024259f31fb5fa.bindPopup(popup_78a4f5e103c5a4fe714b3dd3722761b7)
#         ;
#
#
#
#
#             var marker_b496fe151a9a2a97a02aca3b63e66b16 = L.marker(
#                 [32.299507, -64.790337],
#                 {}
#             ).addTo(map_a1dfbc96f1e19485352da3c6bc97493d);
#
#
#             var icon_3a9ddb8824bea7ca263342e9576c93c6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b496fe151a9a2a97a02aca3b63e66b16.setIcon(icon_3a9ddb8824bea7ca263342e9576c93c6);
#
#
#         var popup_b01164fac600fc3f4d5c29e23fd5a01b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_79661765fe376452a89dccd8a6c467bc = $(`&lt;div id=&quot;html_79661765fe376452a89dccd8a6c467bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hamilton, Bermuda&lt;/div&gt;`)[0];
#             popup_b01164fac600fc3f4d5c29e23fd5a01b.setContent(html_79661765fe376452a89dccd8a6c467bc);
#
#
#         marker_b496fe151a9a2a97a02aca3b63e66b16.bindPopup(popup_b01164fac600fc3f4d5c29e23fd5a01b)
#         ;
#
#
#
#
#             var marker_d057683601286e586246cd748130af50 = L.marker(
#                 [22.302711, 114.177216],
#                 {}
#             ).addTo(map_a1dfbc96f1e19485352da3c6bc97493d);
#
#
#             var icon_bb06b82c19ebf8dfd3d89f1f0367efed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d057683601286e586246cd748130af50.setIcon(icon_bb06b82c19ebf8dfd3d89f1f0367efed);
#
#
#         var popup_2ee0001b338de9d40bbab7eba739c606 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9e7840cfd7f85d49cea5bda304969907 = $(`&lt;div id=&quot;html_9e7840cfd7f85d49cea5bda304969907&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hong Kong&lt;/div&gt;`)[0];
#             popup_2ee0001b338de9d40bbab7eba739c606.setContent(html_9e7840cfd7f85d49cea5bda304969907);
#
#
#         marker_d057683601286e586246cd748130af50.bindPopup(popup_2ee0001b338de9d40bbab7eba739c606)
#         ;
#
#
#
#
#             var marker_93edeef06111ee714926fe06a3615052 = L.marker(
#                 [34.052235, -118.243683],
#                 {}
#             ).addTo(map_a1dfbc96f1e19485352da3c6bc97493d);
#
#
#             var icon_4ea1f75f285877166e299ffd13ef9878 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_93edeef06111ee714926fe06a3615052.setIcon(icon_4

# %%
my_map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3110cdba23b692e8b6c621901de453c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3110cdba23b692e8b6c621901de453c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b3110cdba23b692e8b6c621901de453c = L.map(
#                 &quot;map_b3110cdba23b692e8b6c621901de453c&quot;,
#                 {
#                     center: [9.706386673729778e-14, 16.10398729508073],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f62efc781c0c1c186fea987a6014bad8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b3110cdba23b692e8b6c621901de453c);
#
#
#             var marker_93c79adc27d7acb203e2a6ee2a9a9ed9 = L.marker(
#                 [40.776676, -73.971321],
#                 {}
#             ).addTo(map_b3110cdba23b692e8b6c621901de453c);
#
#
#             var icon_ad3e8c1064a85fd6918bc1edcfce78d1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_93c79adc27d7acb203e2a6ee2a9a9ed9.setIcon(icon_ad3e8c1064a85fd6918bc1edcfce78d1);
#
#
#         var popup_137344ce8618379aca09cd226c0c8d53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f8489a61d0f0275fe4f145aa5b1b2db2 = $(`&lt;div id=&quot;html_f8489a61d0f0275fe4f145aa5b1b2db2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NYC&lt;/div&gt;`)[0];
#             popup_137344ce8618379aca09cd226c0c8d53.setContent(html_f8489a61d0f0275fe4f145aa5b1b2db2);
#
#
#         marker_93c79adc27d7acb203e2a6ee2a9a9ed9.bindPopup(popup_137344ce8618379aca09cd226c0c8d53)
#         ;
#
#
#
#
#             var marker_c9801e2fe6a62c5d800d4c6590cb1518 = L.marker(
#                 [32.299507, -64.790337],
#                 {}
#             ).addTo(map_b3110cdba23b692e8b6c621901de453c);
#
#
#             var icon_f22d46a15e7fc6fce078ecd129247dc3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c9801e2fe6a62c5d800d4c6590cb1518.setIcon(icon_f22d46a15e7fc6fce078ecd129247dc3);
#
#
#         var popup_a068a7015035700e83e8024e3f941917 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b463aeff5701ce34a6f74733fc5f5ec8 = $(`&lt;div id=&quot;html_b463aeff5701ce34a6f74733fc5f5ec8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hamilton, Bermuda&lt;/div&gt;`)[0];
#             popup_a068a7015035700e83e8024e3f941917.setContent(html_b463aeff5701ce34a6f74733fc5f5ec8);
#
#
#         marker_c9801e2fe6a62c5d800d4c6590cb1518.bindPopup(popup_a068a7015035700e83e8024e3f941917)
#         ;
#
#
#
#
#             var marker_d62c65c2706c0ae8f617cfbbbf1c57ab = L.marker(
#                 [22.302711, 114.177216],
#                 {}
#             ).addTo(map_b3110cdba23b692e8b6c621901de453c);
#
#
#             var icon_3ab5d8318567f36de88ef1705f2d232c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d62c65c2706c0ae8f617cfbbbf1c57ab.setIcon(icon_3ab5d8318567f36de88ef1705f2d232c);
#
#
#         var popup_4e7385d4b78b5798d17b8b7b1ea75df8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a0de389723daae1cf0c8bfae4ed24f7b = $(`&lt;div id=&quot;html_a0de389723daae1cf0c8bfae4ed24f7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hong Kong&lt;/div&gt;`)[0];
#             popup_4e7385d4b78b5798d17b8b7b1ea75df8.setContent(html_a0de389723daae1cf0c8bfae4ed24f7b);
#
#
#         marker_d62c65c2706c0ae8f617cfbbbf1c57ab.bindPopup(popup_4e7385d4b78b5798d17b8b7b1ea75df8)
#         ;
#
#
#
#
#             var marker_ba397b145fd1bc8b7512c2375dba61ac = L.marker(
#                 [34.052235, -118.243683],
#                 {}
#             ).addTo(map_b3110cdba23b692e8b6c621901de453c);
#
#
#             var icon_3a3bd03c9c4074cef0d71cee8300b5b0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ba397b145fd1bc8b7512c2375dba61ac.setIcon(icon_3
