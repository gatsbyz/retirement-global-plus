# %%
import folium
import pandas as pd

# %%
my_map3 = folium.Map(location=[13/133932434766733, 16.10398729508073],
    zoom_start=2)

# %%
#setting Markers for selected cities. 
#NYC

mk = folium.Marker([40.776676, -73.971321])
pp = folium.Popup('NYC')
ic = folium.Icon(color='red')

mk.add_child(ic)
mk.add_child(pp)
my_map3.add_child(mk)

#Hamilton, Bermuda
mk2 = folium.Marker([32.299507, -64.790337 ])
pp2 = folium.Popup('Hamilton, Bermuda')
ic2 = folium.Icon(color='blue')

mk2.add_child(ic2)
mk2.add_child(pp2)
my_map3.add_child(mk2)

#Hong Kong

mk3 = folium.Marker([22.302711, 114.177216])
pp3 = folium.Popup('Hong Kong')
ic3 = folium.Icon(color='orange')

mk3.add_child(ic3)
mk3.add_child(pp3)
my_map3.add_child(mk3)

#Los Angeles 
mk4 = folium.Marker([34.052235, -118.243683])
pp4 = folium.Popup('Los Angeles')
ic4 = folium.Icon(color='green')

mk4.add_child(ic4)
mk4.add_child(pp4)
my_map3.add_child(mk4)

#Paris France
mk5 = folium.Marker([48.864716, 2.349014])
pp5 = folium.Popup("Paris, France")
ic5 = folium.Icon(color='pink')

mk5.add_child(ic5)
mk5.add_child(pp5)
my_map3.add_child(mk5)

#Hamilton Canada
mk6 = folium.Marker([43.255203, -79.843826])
pp6 = folium.Popup("Hamilton, Canada")
ic6 = folium.Icon(color="black")

mk6.add_child(ic6)
mk6.add_child(pp6)
my_map3.add_child(mk6)

#Milan Itialy
mk7 = folium.Marker([45.464664, 9.188540])
pp7 = folium.Popup('Milan, Itialy')
ic7 = folium.Icon(color='purple')

mk7.add_child(ic7)
mk7.add_child(pp7)
my_map3.add_child(mk7)

#Bucaramanga Colombia
mk8 = folium.Marker([7.119349, -73.122742])
pp8 = folium.Popup("Bucaramanga, Colombia")
ic8 = folium.Icon(color='cadetblue')

mk8.add_child(ic8)
mk8.add_child(pp8)
my_map3.add_child(mk8)

# Mardrid Spain
mk9 = folium.Marker([40.416729, -3.703339])
pp9 = folium.Popup("Madrid, Spain")
ic9 = folium.Icon(color="beige")

mk9.add_child(ic9)
mk9.add_child(pp9)
my_map3.add_child(mk9)

#Deli, India
mk10 = folium.Marker([28.679079, 77.069710])
pp10 = folium.Popup("Delhi, India")
ic10 = folium.Icon(color="darkgreen")

mk10.add_child(ic10)
mk10.add_child(pp10)
my_map3.add_child(mk10)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_baa2d462038d44eceac405528b9345b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_baa2d462038d44eceac405528b9345b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_baa2d462038d44eceac405528b9345b3 = L.map(
#                 &quot;map_baa2d462038d44eceac405528b9345b3&quot;,
#                 {
#                     center: [9.706386673729778e-14, 16.10398729508073],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c8957761a4e5d05be79b63a7a749847c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_baa2d462038d44eceac405528b9345b3);
#
#
#             var marker_abef226f79376ca0a63e453d5fc18b64 = L.marker(
#                 [40.776676, -73.971321],
#                 {}
#             ).addTo(map_baa2d462038d44eceac405528b9345b3);
#
#
#             var icon_e16f962bbff75f3f740e6e1409054f2c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_abef226f79376ca0a63e453d5fc18b64.setIcon(icon_e16f962bbff75f3f740e6e1409054f2c);
#
#
#         var popup_87d191e5c787d393559a3efa4188a42b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_284e7ba886a5eb4c2f20c4d3f796087d = $(`&lt;div id=&quot;html_284e7ba886a5eb4c2f20c4d3f796087d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NYC&lt;/div&gt;`)[0];
#             popup_87d191e5c787d393559a3efa4188a42b.setContent(html_284e7ba886a5eb4c2f20c4d3f796087d);
#
#
#         marker_abef226f79376ca0a63e453d5fc18b64.bindPopup(popup_87d191e5c787d393559a3efa4188a42b)
#         ;
#
#
#
#
#             var marker_98f45fae2723282bc35b82b27df42f80 = L.marker(
#                 [32.299507, -64.790337],
#                 {}
#             ).addTo(map_baa2d462038d44eceac405528b9345b3);
#
#
#             var icon_4c4ad39d38f72c09c1da92c48fc7dac7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_98f45fae2723282bc35b82b27df42f80.setIcon(icon_4c4ad39d38f72c09c1da92c48fc7dac7);
#
#
#         var popup_716ae1900d591d708a80cdc548447097 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_774c0829e435b0491d6795ad3d8f6b9c = $(`&lt;div id=&quot;html_774c0829e435b0491d6795ad3d8f6b9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hamilton, Bermuda&lt;/div&gt;`)[0];
#             popup_716ae1900d591d708a80cdc548447097.setContent(html_774c0829e435b0491d6795ad3d8f6b9c);
#
#
#         marker_98f45fae2723282bc35b82b27df42f80.bindPopup(popup_716ae1900d591d708a80cdc548447097)
#         ;
#
#
#
#
#             var marker_8c8b0c1ae9cf15dc9a4965dcdeeb4ee1 = L.marker(
#                 [22.302711, 114.177216],
#                 {}
#             ).addTo(map_baa2d462038d44eceac405528b9345b3);
#
#
#             var icon_d85271248aff239fcade751610060667 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8c8b0c1ae9cf15dc9a4965dcdeeb4ee1.setIcon(icon_d85271248aff239fcade751610060667);
#
#
#         var popup_60afa90423db679aacb321b11ca694be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7e56a193c04df945e70cce686968bfd7 = $(`&lt;div id=&quot;html_7e56a193c04df945e70cce686968bfd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hong Kong&lt;/div&gt;`)[0];
#             popup_60afa90423db679aacb321b11ca694be.setContent(html_7e56a193c04df945e70cce686968bfd7);
#
#
#         marker_8c8b0c1ae9cf15dc9a4965dcdeeb4ee1.bindPopup(popup_60afa90423db679aacb321b11ca694be)
#         ;
#
#
#
#
#             var marker_e0d236bbf912e54687afd43f05a35ab3 = L.marker(
#                 [34.052235, -118.243683],
#                 {}
#             ).addTo(map_baa2d462038d44eceac405528b9345b3);
#
#
#             var icon_aa5c35419248cc42f83edc34338a92fe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e0d236bbf912e54687afd43f05a35ab3.setIcon(icon_a

# %%
my_map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_baa2d462038d44eceac405528b9345b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_baa2d462038d44eceac405528b9345b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_baa2d462038d44eceac405528b9345b3 = L.map(
#                 &quot;map_baa2d462038d44eceac405528b9345b3&quot;,
#                 {
#                     center: [9.706386673729778e-14, 16.10398729508073],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c8957761a4e5d05be79b63a7a749847c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_baa2d462038d44eceac405528b9345b3);
#
#
#             var marker_abef226f79376ca0a63e453d5fc18b64 = L.marker(
#                 [40.776676, -73.971321],
#                 {}
#             ).addTo(map_baa2d462038d44eceac405528b9345b3);
#
#
#             var icon_e16f962bbff75f3f740e6e1409054f2c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_abef226f79376ca0a63e453d5fc18b64.setIcon(icon_e16f962bbff75f3f740e6e1409054f2c);
#
#
#         var popup_87d191e5c787d393559a3efa4188a42b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_284e7ba886a5eb4c2f20c4d3f796087d = $(`&lt;div id=&quot;html_284e7ba886a5eb4c2f20c4d3f796087d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NYC&lt;/div&gt;`)[0];
#             popup_87d191e5c787d393559a3efa4188a42b.setContent(html_284e7ba886a5eb4c2f20c4d3f796087d);
#
#
#         marker_abef226f79376ca0a63e453d5fc18b64.bindPopup(popup_87d191e5c787d393559a3efa4188a42b)
#         ;
#
#
#
#
#             var marker_98f45fae2723282bc35b82b27df42f80 = L.marker(
#                 [32.299507, -64.790337],
#                 {}
#             ).addTo(map_baa2d462038d44eceac405528b9345b3);
#
#
#             var icon_4c4ad39d38f72c09c1da92c48fc7dac7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_98f45fae2723282bc35b82b27df42f80.setIcon(icon_4c4ad39d38f72c09c1da92c48fc7dac7);
#
#
#         var popup_716ae1900d591d708a80cdc548447097 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_774c0829e435b0491d6795ad3d8f6b9c = $(`&lt;div id=&quot;html_774c0829e435b0491d6795ad3d8f6b9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hamilton, Bermuda&lt;/div&gt;`)[0];
#             popup_716ae1900d591d708a80cdc548447097.setContent(html_774c0829e435b0491d6795ad3d8f6b9c);
#
#
#         marker_98f45fae2723282bc35b82b27df42f80.bindPopup(popup_716ae1900d591d708a80cdc548447097)
#         ;
#
#
#
#
#             var marker_8c8b0c1ae9cf15dc9a4965dcdeeb4ee1 = L.marker(
#                 [22.302711, 114.177216],
#                 {}
#             ).addTo(map_baa2d462038d44eceac405528b9345b3);
#
#
#             var icon_d85271248aff239fcade751610060667 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8c8b0c1ae9cf15dc9a4965dcdeeb4ee1.setIcon(icon_d85271248aff239fcade751610060667);
#
#
#         var popup_60afa90423db679aacb321b11ca694be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7e56a193c04df945e70cce686968bfd7 = $(`&lt;div id=&quot;html_7e56a193c04df945e70cce686968bfd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hong Kong&lt;/div&gt;`)[0];
#             popup_60afa90423db679aacb321b11ca694be.setContent(html_7e56a193c04df945e70cce686968bfd7);
#
#
#         marker_8c8b0c1ae9cf15dc9a4965dcdeeb4ee1.bindPopup(popup_60afa90423db679aacb321b11ca694be)
#         ;
#
#
#
#
#             var marker_e0d236bbf912e54687afd43f05a35ab3 = L.marker(
#                 [34.052235, -118.243683],
#                 {}
#             ).addTo(map_baa2d462038d44eceac405528b9345b3);
#
#
#             var icon_aa5c35419248cc42f83edc34338a92fe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e0d236bbf912e54687afd43f05a35ab3.setIcon(icon_a
