# %%
import folium
import pandas as pd

# %%
my_map3 = folium.Map(location=[13/133932434766733, 16.10398729508073],
    zoom_start=3)

# %%
#setting Markers for selected cities. 
#NYC

mk = folium.Marker([40.776676, -73.971321])
pp = folium.Popup('NYC')
ic = folium.Icon(color='red')

mk.add_child(ic)
mk.add_child(pp)
my_map3.add_child(mk)

#Hamilton, Bermuda
mk2 = folium.Marker([32.299507, -64.790337 ])
pp2 = folium.Popup('Hamilton, Bermuda')
ic2 = folium.Icon(color='blue')

mk2.add_child(ic2)
mk2.add_child(pp2)
my_map3.add_child(mk2)

#Hong Kong

mk3 = folium.Marker([22.302711, 114.177216])
pp3 = folium.Popup('Hong Kong')
ic3 = folium.Icon(color='orange')

mk3.add_child(ic3)
mk3.add_child(pp3)
my_map3.add_child(mk3)

#Los Angeles 
mk4 = folium.Marker([34.052235, -118.243683])
pp4 = folium.Popup('Los Angeles')
ic4 = folium.Icon(color='green')

mk4.add_child(ic4)
mk4.add_child(pp4)
my_map3.add_child(mk4)

#Paris France
mk5 = folium.Marker([48.864716, 2.349014])
pp5 = folium.Popup("Paris, France")
ic5 = folium.Icon(color='pink')

mk5.add_child(ic5)
mk5.add_child(pp5)
my_map3.add_child(mk5)

#Hamilton Canada
mk6 = folium.Marker([43.255203, -79.843826])
pp6 = folium.Popup("Hamilton, Canada")
ic6 = folium.Icon(color="black")

mk6.add_child(ic6)
mk6.add_child(pp6)
my_map3.add_child(mk6)

#Milan Itialy
mk7 = folium.Marker([45.464664, 9.188540])
pp7 = folium.Popup('Milan, Itialy')
ic7 = folium.Icon(color='purple')

mk7.add_child(ic7)
mk7.add_child(pp7)
my_map3.add_child(mk7)

#Bucaramanga Colombia
mk8 = folium.Marker([7.119349, -73.122742])
pp8 = folium.Popup("Bucaramanga, Colombia")
ic8 = folium.Icon(color='cadetblue')

mk8.add_child(ic8)
mk8.add_child(pp8)
my_map3.add_child(mk8)

# Mardrid Spain
mk9 = folium.Marker([40.416729, -3.703339])
pp9 = folium.Popup("Madrid, Spain")
ic9 = folium.Icon(color="beige")

mk9.add_child(ic9)
mk9.add_child(pp9)
my_map3.add_child(mk9)

#Deli, India
mk10 = folium.Marker([28.679079, 77.069710])
pp10 = folium.Popup("Delhi, India")
ic10 = folium.Icon(color="darkgreen")

mk10.add_child(ic10)
mk10.add_child(pp10)
my_map3.add_child(mk10)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
my_map3.save("Interactive retirement map")
