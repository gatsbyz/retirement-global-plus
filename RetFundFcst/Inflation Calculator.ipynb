# %%
# Inflation Calculator

# Calculator to Compound Interests (Convert to Questionary)


rate = 0.0375
cost_of_living = 60000
current_age = 40
remaining_years = 80 - current-age
remaining_years = 40
yearly_contribution = 50000

dataframe.cumprod()



cost_of_living.cumprod()
portfolio_balance > cost_of_living.cumprod()

# Portfolio Balance 

year1 = 20000 
year2 = 30000
year3 = 40000
year4 = 50000
year5 = 60000


year5_cumbalance = 300000
year5_affordableyears = 300000 - (cost_of_living * remaining_years)

if portfolio_balance > affordableyears

final_portfolio_balance = current_balance + (contribution * remaining_years)

def can_you_retire(cost_of_living, remaining_years, portfolio_balance):
    if portfolio_balance > (cost_of_living * remaining_years):
        print(' 



#needed inputs




Cities
Rate of Inflation related to specific city (pulled from API)
Time formula based on years to earliest retirement
real_rate



start_over = 'true'   
while start_over == 'true':    
    cost_of_living = int('variable with cost of living for city should enter after city selection)'
    inf_rate = float(input('type interest rate'))
    time = int(input('enter number of years to invest'))           
    real_rate = rate * 0.01
    i = 0



    print('total', cost_of_living * (1 + real_rate))

    while i < time:
        cost_of_living = (cost_of_living) * (1 + real_rate)
        i = i + 1
        print('total', cost_of_living)

    #redo_program = (input('to restart type y or to quite type any key'))
    #if redo_program =='y':
    #    start_over = 'true'
    #else:
    #    start_over = 'null'
